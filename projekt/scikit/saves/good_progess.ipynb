# %%
# !pip install sktime
# Out:
# Requirement already satisfied: sktime in c:\users\danne\anaconda3\lib\site-packages (0.36.0)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.4.2)
# Requirement already satisfied: numpy<2.3,>=1.21 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.26.4)
# Requirement already satisfied: packaging in c:\users\danne\anaconda3\lib\site-packages (from sktime) (24.1)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (2.2.2)
# Requirement already satisfied: scikit-base<0.13.0,>=0.6.1 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (0.12.0)
# Requirement already satisfied: scikit-learn<1.7.0,>=0.24 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.5.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danne\anaconda3\lib\site-packages (from pandas<2.3.0,>=1.1->sktime) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danne\anaconda3\lib\site-packages (from pandas<2.3.0,>=1.1->sktime) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danne\anaconda3\lib\site-packages (from pandas<2.3.0,>=1.1->sktime) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\danne\anaconda3\lib\site-packages (from scikit-learn<1.7.0,>=0.24->sktime) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\danne\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.1->sktime) (1.16.0)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from time import sleep
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sktime.classification.kernel_based import RocketClassifier
from sktime.datatypes import convert_to
from sktime.datatypes._panel._convert import from_nested_to_3d_numpy
from sktime.datatypes import check_is_mtype

# %%
nr_of_samples_in_one_batch = 100

# %%
def convert(df, list_cols=None, label_col='label'):
    if list_cols is None:
        list_cols = ['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z']

    # 1. Reset index so we have a 'instance' column
    df = df.reset_index(drop=True).rename_axis('instance').reset_index()

    # 2. Explode list columns
    df = df.explode(list_cols, ignore_index=True)

    # 3. Create a 'time' column for each exploded element
    df['time'] = df.groupby('instance').cumcount()

    # 4. Set a MultiIndex of (instance, time)
    df = df.set_index(['instance', 'time'])

    # 5. Convert all non-label columns to float
    numeric_cols = [col for col in df.columns if col != label_col]
    df[numeric_cols] = df[numeric_cols].astype(float)

    return df

# %%
def read_X_samples(X, nr, samples):
    return samples.iloc[(nr*X):(nr*X+X), :]

# %%
def addEntryToDataFrame(df, data, label):
    new_entry = {f"feature_{i}": [np.array(data.iloc[:, i].values, dtype=np.float64)]  # Wrap in list
                 for i in range(data.shape[1])}
    new_entry["label"] = [label]  # Wrap label in list
    
    # Convert to DataFrame
    df_entry = pd.DataFrame(new_entry)

    # Concatenate
    df = pd.concat([df, df_entry], ignore_index=True)
    return df

# %%
def concatenate_dataFrames(dF1, dF2):
    frame = [dF1, dF2]
    return pd.concat(frame, ignore_index=True)

# %%
def renameFeatures(dF):
    preferred_names = ["acc_x", "acc_y", "acc_z", "gyr_x", "gyr_y", "gyr_z", "label"]
    dF.columns = preferred_names[:len(preferred_names)]
    return dF

# %%
def addWholeDatasetToDataFrame(dF, data, label):
    nr_of_batches = round(data.dropna(how='all').shape[0] / nr_of_samples_in_one_batch)
    
    for i in range(nr_of_batches):
        batch = read_X_samples(nr_of_samples_in_one_batch, i, data)
        dF = addEntryToDataFrame(dF, batch, label)
    dF = renameFeatures(dF)
    return dF

# %%
def readFile_addToDataFrame(filename, dF, label_name):
    motion = pd.read_csv(filename, na_filter=False, sep=r"\s+", header=None, dtype=np.float64)
    dF = addWholeDatasetToDataFrame(dF, motion, label_name)
    dF["label"] = dF["label"].astype("category")
    return dF

# %%
def shuffle_instances(df):
    # Get unique instance values and shuffle them
    shuffled_instances = shuffle(df.index.levels[0])  # Shuffle the instances
    
    # Reorder the DataFrame based on shuffled instances while keeping time order intact
    df_shuffled = pd.concat([df.loc[i] for i in shuffled_instances], keys=shuffled_instances)

    return df_shuffled

# %%
dF_updown = pd.DataFrame()
dF_circles = pd.DataFrame()

# %%
dF_updown = readFile_addToDataFrame('up_down2.txt', dF_updown, 'Up and down')
dF_circles = readFile_addToDataFrame('circles2.txt', dF_circles, 'Circle')

# %%
dF_updown['acc_x'].dtype, dF_updown['acc_x'][0].dtype, dF_updown['label'].dtype
# Out:
# (dtype('O'),
#  dtype('float64'),
#  CategoricalDtype(categories=['Up and down'], ordered=False, categories_dtype=object))

# %%
print(check_is_mtype(dF_updown, "nested_univ")) # Check if type is correct for sktime
# Out:
# False

# %%
print(type(dF_updown.iloc[0, 0]))
# Out:
# <class 'numpy.ndarray'>

# %%
dF_updown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   33 non-null     object
#  1   acc_y   33 non-null     object
#  2   acc_z   33 non-null     object
#  3   gyr_x   33 non-null     object
#  4   gyr_y   33 non-null     object
#  5   gyr_z   33 non-null     object
#  6   label   33 non-null     category
# dtypes: category(1), object(6)
# memory usage: 1.8+ KB

# %%
dF_circles
# Out:
#                                                 acc_x  \
# 0   [-42.97, -50.78, -50.29, -42.97, -36.13, -40.5...
# 1   [-57.62, -45.41, -48.34, -56.15, -62.5, -39.06...
# 2   [-41.99, -48.83, -35.16, -48.34, -51.27, -48.3...
# 3   [-54.2, -45.9, -50.29, -40.04, -34.67, -44.43,...
# 4   [-42.48, -54.69, -56.64, -33.2, -45.9, -41.99,...
# 5   [-50.78, -43.46, -40.04, -57.62, -45.41, -46.8...
# 6   [-210.94, -226.56, -7.81, -177.73, -324.71, -1...
# 7   [-69.34, -24.41, -23.93, -24.9, -23.93, -44.92...
# 8   [-8.3, -18.55, -24.41, -15.63, -20.02, -23.44,...
# 9   [-17.09, -14.65, -21.0, -22.95, -17.09, -23.44...
# 10  [181.64, 198.73, 323.73, 228.03, 24.41, -111.8...
# 11  [438.48, 590.33, 414.06, 380.86, 496.09, 331.5...
# 12  [-523.44, -323.24, -523.44, -103.03, -60.55, 2...
# 13  [223.63, 225.1, 78.12, 106.93, -137.21, 316.89...
# 14  [145.51, 89.36, 431.15, 325.68, 287.6, -33.69,...
# 15  [-139.16, -353.03, -493.16, -365.23, -561.04, ...
# 16  [509.28, 334.96, 273.93, 381.35, 358.89, 342.7...
# 17  [-519.53, -585.45, -390.62, -418.46, -309.08, ...
# 18  [334.47, 378.91, 299.32, 504.88, 492.68, 464.8...
# 19  [-225.1, 55.66, 155.76, 480.47, 156.25, 197.75...
# 20  [-319.82, -368.16, -470.21, -543.46, -534.67, ...
# 21  [387.21, 364.26, 276.86, 217.29, 9.28, 73.24, ...
# 22  [70.8, 255.37, 137.7, 354.0, 245.61, 349.12, 5...
# 23  [-682.13, -548.34, -444.34, -374.02, -251.46, ...
# 24  [189.94, 788.09, -527.34, 18.55, -143.55, -82....
# 25  [328.61, 309.57, 260.74, 802.25, 218.75, 493.1...
# 26  [-507.81, -642.58, -594.73, -347.66, -373.05, ...
# 27  [68.85, -120.12, -307.13, -194.82, -453.12, -7...
# 28  [519.53, 392.09, 450.68, 480.47, 536.13, 578.6...
# 29  [-176.76, -275.39, -425.29, -288.57, -149.41, ...
# 30  [163.57, -76.66, 128.91, -118.16, -69.82, -315...
# 14  [2.59, -7.53, 2.59, 1.22, -0.91, 0.76, -0.09, ...
# 15  [-3.63, 4.7, -0.37, -0.98, -11.34, -9.51, -5.0...
# 16  [2.99, 6.22, 2.62, 11.49, 1.89, 0.21, 4.82, 11...
# 17  [0.64, 0.7, 1.86, -5.06, -5.3, -7.77, -0.12, -...
# 18  [-3.05, 4.66, 3.96, -0.79, 0.88, 5.76, 4.15, -...
# 19  [0.52, -0.58, -6.89, 4.12, -5.03, 0.18, -2.07,...
# 20  [-9.94, -6.01, 3.14, -0.21, -7.87, -3.6, -3.05...
# 21  [7.35, -2.96, -2.71, 4.39, 5.12, -1.19, 1.89, ...
# 22  [2.41, 2.41, 6.19, 10.37, 5.73, 5.24, 6.43, 0....
# 23  [-3.2, 1.95, -4.79, -7.62, -2.35, -1.86, -1.34...
# 24  [42.62, -44.85, -47.1, 12.32, -5.03, -13.9, -1...
# 25  [1.25, -16.8, 3.75, -4.05, 13.78, 11.65, 10.0,...
# 26  [-6.4, 2.84, 2.13, -8.57, -0.37, -3.57, 4.82, ...
# 27  [-3.26, -4.05, -4.3, -9.63, -4.45, 0.98, -4.97...
# 28  [-7.99, 7.01, 7.38, -3.96, -2.53, 4.02, -2.2, ...
# 29  [-7.13, 1.74, -9.66, 0.15, 3.54, 4.09, 1.28, 0...
# 30  [9.66, -0.79, -3.41, 8.35, 3.05, -8.69, -10.61...
# 31  [4.05, 5.95, 4.05, -3.78, 2.62, -2.47, 12.2, 1...
# 32  [2.87, -9.82, -6.77, -7.53, 0.46, -9.73, 24.66...
#
#                                                 gyr_y  \
# 0   [-0.91, -2.8, -1.25, -1.25, -2.93, -0.24, -2.1...
# 1   [-1.55, -2.74, -2.32, -2.87, -0.7, -1.22, -2.3...
# 2   [-1.1, -1.31, -1.46, -2.47, -0.82, 0.49, -0.98...
# 3   [0.09, -1.49, -1.25, 0.52, -0.21, -3.6, 0.49, ...
# 4   [-1.34, 0.76, -1.98, 0.03, 0.82, -0.95, -0.37,...
# 5   [-0.09, -2.53, -2.44, 0.09, -2.9, 0.18, -0.82,...
# 6   [-0.88, 4.21, 0.82, -0.21, 9.66, 16.04, 23.05,...
# 7   [-2.38, -1.1, -1.86, 0.15, -1.71, -0.03, -0.61...
# 8   [-1.07, -1.37, -5.12, -1.55, -0.18, -0.76, -2....
# 9   [-0.85, -1.62, -2.2, -0.85, -2.2, -0.91, -2.62...
# 10  [-8.87, 1.52, 4.27, -4.51, -4.88, 0.95, -4.82,...
# 11  [-3.2, -7.77, -4.51, -0.95, -2.59, -0.82, -7.3...
# 12  [0.95, -1.77, 5.58, -6.89, 1.62, -7.41, -7.53,...
# 13  [-1.89, -3.87, -0.88, -2.53, 3.93, -7.26, 2.65...
# 14  [-12.2, 2.44, 0.15, 11.01, -6.07, -8.87, 4.27,...
# 15  [5.12, 1.68, 0.91, -14.15, 1.98, -3.45, -3.6, ...
# 16  [-7.87, -7.99, -2.74, 2.9, -8.05, 2.2, 4.36, -...
# 17  [2.23, 1.65, -1.46, -3.29, -14.82, -8.81, 2.77...
# 18  [4.42, -5.79, -1.28, 2.8, 4.21, 2.29, -0.79, 1...
# 19  [7.29, -10.52, -4.6, -7.65, -5.43, 14.94, -4.9...
# 20  [-1.65, -8.75, -3.45, 2.01, -14.18, -5.85, 0.6...
# 21  [3.11, -5.43, 1.19, -10.43, 1.52, -6.22, 3.02,...
# 22  [-0.82, -10.3, 13.11, 10.52, -12.23, -1.55, 8....
# 23  [-0.73, -7.01, -2.93, -4.42, 4.45, 3.05, -2.96...
# 24  [2.32, -0.15, -3.32, -4.97, -8.17, 0.55, -10.8...
# 25  [-4.63, -4.57, 9.27, 12.44, 7.26, -3.35, 1.52,...
# 26  [4.82, -11.8, 3.63, -3.11, 6.74, -5.21, 1.1, 1...
# 27  [7.1, -2.96, -5.46, 0.67, -10.7, -12.35, -6.95...
# 28  [13.23, 0.0, -2.47, 1.04, 4.48, 3.87, -6.37, -...
# 29  [-8.48, 13.63, 12.47, 11.16, -9.27, -3.05, 11....
# 30  [1.71, -2.07, -15.98, -7.1, -0.85, -9.85, -4.0...
# 31  [-3.45, -1.86, -0.52, -2.8, -3.54, -3.69, 2.9,...
# 32  [-0.3, -3.63, -4.02, -1.37, -0.37, -3.08, -1.3...
#
#                                                 gyr_z   label
# 0   [0.67, 1.49, -0.98, -2.04, -1.71, 0.09, -1.16,...  Circle
# 1   [-0.52, 1.16, -0.46, 0.46, 1.49, -2.9, -0.15, ...  Circle
# 2   [1.62, -0.67, 1.01, -1.16, 1.65, -0.24, -0.61,...  Circle
# 3   [-2.44, 1.07, -2.01, -0.67, 0.27, 1.65, -1.71,...  Circle
# 4   [1.4, 0.61, -0.18, -1.22, -0.7, -0.12, -1.46, ...  Circle
# 5   [-1.04, 1.04, 0.61, -1.01, -0.73, -1.19, 1.89,...  Circle
# 6   [34.97, 24.76, 15.64, 19.24, 24.6, -3.23, -11....  Circle
# 7   [-1.62, -1.01, -0.98, -1.92, 1.22, 7.62, 7.96,...  Circle
# 8   [0.88, 0.3, 0.49, 0.88, -1.74, 2.13, 1.07, -3....  Circle
# 9   [0.15, -0.21, 1.98, 2.35, 0.73, 1.4, 2.59, -0....  Circle
# 10  [7.87, 0.67, 2.32, -6.65, 5.55, 15.21, 18.35, ...  Circle
# 11  [-55.95, -54.94, -50.64, -32.99, -16.98, -15.0...  Circle
# 12  [-8.38, -10.73, -45.3, -22.38, -30.4, -36.31, ...  Circle
# 13  [5.06, 3.32, 18.6, 43.45, 58.08, 34.66, 56.37,...  Circle
# 14  [-56.95, -46.13, -49.57, -29.33, -27.93, -34.7...  Circle
# 15  [64.97, 77.01, 80.73, 52.53, 26.34, 22.38, -15...  Circle
# 16  [-66.83, -73.63, -41.59, -57.35, -21.46, -17.8...  Circle
# 17  [47.8, 64.73, 42.99, 4.05, -10.06, 10.12, -19....  Circle
# 18  [-44.48, -30.82, -34.7, -13.48, -3.08, 12.9, 1...  Circle
# 19  [-56.95, -66.86, -73.14, -63.66, -45.82, -45.5...  Circle
# 20  [55.85, 57.99, 58.84, 60.46, 59.66, 68.11, -2....  Circle
# 21  [61.04, 20.91, -20.0, -35.98, -21.92, -22.23, ...  Circle
# 22  [-40.82, -32.01, -26.31, -47.8, -61.22, -53.72...  Circle
# 23  [-0.85, 4.02, 8.32, 14.39, -8.96, -6.01, -37.2...  Circle
# 24  [31.86, 24.36, 14.63, 27.47, 38.93, 68.17, 80....  Circle
# 25  [-53.02, -28.72, -46.31, -20.98, -25.88, -40.4...  Circle
# 26  [78.26, 66.22, 21.86, 6.46, -8.63, -33.05, -48...  Circle
# 27  [30.21, 50.91, 71.04, 77.1, 90.03, 79.85, 84.0...  Circle
# 28  [-25.18, -72.8, -65.58, -36.65, -27.77, -1.13,...  Circle
# 29  [29.76, 4.09, 13.87, -18.45, -22.99, -12.62, -...  Circle
# 30  [28.78, 10.03, 26.74, 13.38, 27.59, 26.31, 42....  Circle
# 31  [-67.35, -77.93, -50.21, -50.82, -28.93, -44.7...  Circle
# 32  [19.3, 14.12, -5.46, -24.54, -32.41, -48.93, -...  Circle

# %%
print(len(dF_circles.loc[0, 'acc_x']))

for i in range(33):
    print(len(dF_circles.loc[i, 'acc_x']))

print(dF_circles.loc[10, 'acc_x'])
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# [ 181.64  198.73  323.73  228.03   24.41 -111.82 -319.34 -191.41 -280.76
#  -436.52 -373.54 -159.18 -259.28  -83.98 -130.37 -104.49   83.98  324.22
#   296.87  355.96  371.09  487.79  295.41  164.55  183.59  202.15  272.95
#    97.17  -32.23 -134.77 -211.43  -41.99 -109.37 -539.06 -233.4  -268.07
#  -321.78 -316.41 -278.32 -389.65  -61.52 -194.34 -187.99  -41.99  157.23
#   292.97   13.67  306.64  462.4   274.41  317.38  212.89  129.39  211.43
#   172.85  -30.27    8.3  -210.94 -330.08 -211.43 -387.21 -453.12 -421.39
#  -349.61 -217.29 -283.69 -202.64 -246.09  -48.83 -239.26   61.52  -59.57
#   291.5   333.98  411.13  224.61  630.37  320.31  279.79  137.21  178.22
#   180.18  311.04   40.53  -73.73 -271.97 -167.48 -523.44 -288.57 -446.29
#  -564.45 -334.47 -323.73 -394.04 -187.99 -105.96 -177.73   33.69  104.
#   127.93]

# %%
totalDataFrame = concatenate_dataFrames(dF_circles, dF_updown)

# %%
dF_circles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   33 non-null     object
#  1   acc_y   33 non-null     object
#  2   acc_z   33 non-null     object
#  3   gyr_x   33 non-null     object
#  4   gyr_y   33 non-null     object
#  5   gyr_z   33 non-null     object
#  6   label   33 non-null     category
# dtypes: category(1), object(6)
# memory usage: 1.8+ KB

# %%
dF_updown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   33 non-null     object
#  1   acc_y   33 non-null     object
#  2   acc_z   33 non-null     object
#  3   gyr_x   33 non-null     object
#  4   gyr_y   33 non-null     object
#  5   gyr_z   33 non-null     object
#  6   label   33 non-null     category
# dtypes: category(1), object(6)
# memory usage: 1.8+ KB

# %%
totalDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   66 non-null     object
#  1   acc_y   66 non-null     object
#  2   acc_z   66 non-null     object
#  3   gyr_x   66 non-null     object
#  4   gyr_y   66 non-null     object
#  5   gyr_z   66 non-null     object
#  6   label   66 non-null     object
# dtypes: object(7)
# memory usage: 3.7+ KB

# %%
#for row in range(len(totalDataFrame)):
 #   print(totalDataFrame.iloc[row])

# %%
totalDataFrame
# Out:
#                                                 acc_x  \
# 0   [-42.97, -50.78, -50.29, -42.97, -36.13, -40.5...
# 1   [-57.62, -45.41, -48.34, -56.15, -62.5, -39.06...
# 2   [-41.99, -48.83, -35.16, -48.34, -51.27, -48.3...
# 3   [-54.2, -45.9, -50.29, -40.04, -34.67, -44.43,...
# 4   [-42.48, -54.69, -56.64, -33.2, -45.9, -41.99,...
# ..                                                ...
# 61  [-69.82, -174.8, -341.31, -406.74, -286.13, -2...
# 62  [-122.56, -74.71, -38.57, 7.81, -0.98, -114.26...
# 63  [-153.32, -193.36, -132.32, 10.25, -106.93, -2...
# 64  [-37.11, -13.18, -82.52, -35.16, -89.36, -174....
# 65  [-94.24, -62.99, -59.57, -54.2, -38.57, -44.92...
#
#                                                 acc_y  \
# 0   [1.95, 2.44, 0.0, 10.25, 7.81, 0.49, 0.98, 6.8...
# 1   [-2.44, 10.74, 5.86, 0.98, -5.37, 0.49, 6.84, ...
# 2   [-1.46, -7.32, -6.35, -2.93, -0.49, 5.86, 2.44...
# 3   [3.91, -8.3, -0.49, -0.98, 8.79, 5.86, -10.74,...
# 4   [-0.49, -7.81, -4.39, -7.81, 3.42, 12.7, -2.93...
# ..                                                ...
# 61  [71.78, -131.35, -372.56, -536.62, -589.84, -5...
# 62  [274.41, 166.5, 139.16, 107.42, 178.22, 345.21...
# 63  [-476.07, -490.23, -624.51, -532.71, -372.07, ...
# 64  [330.57, 314.45, 230.47, 116.7, 53.22, -56.64,...
# 65  [100.59, 75.68, 48.83, 196.29, 208.01, 177.73,...
#
#                                                 acc_z  \
# 0   [1033.2, 1032.23, 1041.5, 1035.64, 1046.88, 10...
# 1   [1041.5, 1060.55, 1041.02, 1038.57, 1042.48, 1...
# 2   [1042.97, 1042.48, 1041.5, 1045.41, 1050.78, 1...
# 3   [1041.99, 1045.41, 1032.23, 1035.16, 1042.48, ...
# 4   [1039.06, 1046.39, 1042.48, 1045.9, 1035.64, 1...
# ..                                                ...
# 61  [1024.9, 1546.39, 1828.13, 2005.86, 2131.35, 2...
# 62  [259.77, 142.09, 30.76, 6.35, -49.8, -68.36, -...
# 63  [1956.54, 2165.53, 2293.95, 1994.63, 1751.95, ...
# 64  [8.3, 141.11, 514.16, 786.13, 1224.61, 1683.11...
# 65  [987.3, 762.21, 553.71, 396.97, 273.44, 146.97...
#
#                                                 gyr_x  \
# 0   [-1.37, -1.34, -0.43, -2.44, -1.52, -2.35, -3....
# 1   [0.3, -1.34, 0.15, -0.21, -1.37, -3.57, -3.41,...
# 2   [0.7, -2.01, 0.52, -0.06, 1.22, -1.95, -1.19, ...
# 3   [-0.95, -0.37, -1.13, -1.8, -0.4, -0.27, -0.37...
# 4   [0.43, -1.71, -1.83, -2.71, -0.46, -1.55, -2.9...
# ..                                                ...
# 61  [108.9, 108.11, 88.6, 68.35, 33.05, -2.01, -2....
# 62  [-65.61, -42.8, -30.52, -29.12, -16.04, 12.59,...
# 63  [10.82, -7.1, -30.21, -60.12, -97.71, -107.59,...
# 64  [67.2, 100.18, 123.78, 126.16, 125.98, 125.61,...
# 65  [-115.27, -108.63, -105.52, -95.79, -73.05, -5...
#
#                                                 gyr_y  \
# 0   [-0.91, -2.8, -1.25, -1.25, -2.93, -0.24, -2.1...
# 1   [-1.55, -2.74, -2.32, -2.87, -0.7, -1.22, -2.3...
# 2   [-1.1, -1.31, -1.46, -2.47, -0.82, 0.49, -0.98...
# 3   [0.09, -1.49, -1.25, 0.52, -0.21, -3.6, 0.49, ...
# 4   [-1.34, 0.76, -1.98, 0.03, 0.82, -0.95, -0.37,...
# ..                                                ...
# 61  [-67.93, -87.96, -101.89, -87.07, -53.81, -47....
# 62  [30.58, 44.18, 50.64, 37.93, 4.79, -23.38, -37...
# 63  [6.37, 58.84, 31.65, -6.71, -15.37, -10.15, 8....
# 64  [-1.13, -12.07, -28.81, -52.84, -56.01, -66.65...
# 65  [-2.68, 19.45, 23.84, 28.87, 31.37, 29.15, 21....
#
#                                                 gyr_z        label
# 0   [0.67, 1.49, -0.98, -2.04, -1.71, 0.09, -1.16,...       Circle
# 1   [-0.52, 1.16, -0.46, 0.46, 1.49, -2.9, -0.15, ...       Circle
# 2   [1.62, -0.67, 1.01, -1.16, 1.65, -0.24, -0.61,...       Circle
# 3   [-2.44, 1.07, -2.01, -0.67, 0.27, 1.65, -1.71,...       Circle
# 4   [1.4, 0.61, -0.18, -1.22, -0.7, -0.12, -1.46, ...       Circle
# ..                                                ...          ...
# 61  [-2.93, 7.29, -13.63, -27.87, -21.16, -23.81, ...  Up and down
# 62  [23.02, 30.43, 36.89, 38.63, 21.52, -6.86, -17...  Up and down
# 63  [17.68, 25.21, 24.18, 6.04, -8.11, -7.07, 8.45...  Up and down
# 64  [9.05, 13.38, 12.65, 0.98, -26.98, -38.72, -37...  Up and down
# 65  [7.47, 22.2, 5.43, 7.93, 12.77, 12.53, 11.49, ...  Up and down
#
# [66 rows x 7 columns]

# %%
totalDataFrame = convert(totalDataFrame)

# %%
totalDataFrame
# Out:
#                 acc_x   acc_y    acc_z   gyr_x  gyr_y  gyr_z        label
# instance time
# 0        0     -42.97    1.95  1033.20   -1.37  -0.91   0.67       Circle
#          1     -50.78    2.44  1032.23   -1.34  -2.80   1.49       Circle
#          2     -50.29    0.00  1041.50   -0.43  -1.25  -0.98       Circle
#          3     -42.97   10.25  1035.64   -2.44  -1.25  -2.04       Circle
#          4     -36.13    7.81  1046.88   -1.52  -2.93  -1.71       Circle
# ...               ...     ...      ...     ...    ...    ...          ...
# 65       95     17.09  345.21   120.12  109.05 -11.01  -0.64  Up and down
#          96     -4.88  309.08   415.04  141.52 -24.48   1.37  Up and down
#          97     27.34  197.27   721.68  154.60 -32.01  -0.37  Up and down
#          98      7.81  142.09  1186.52  158.63 -43.96  -4.27  Up and down
#          99   -106.93  -36.62  1777.34  147.44 -66.68 -19.21  Up and down
#
# [6600 rows x 7 columns]

# %%
totalDataFrame_shuffled = shuffle_instances(totalDataFrame)

# %%
totalDataFrame_shuffled
# Out:
#                 acc_x   acc_y    acc_z  gyr_x  gyr_y  gyr_z        label
# instance time
# 20       0    -319.82 -238.77  1086.91  -9.94  -1.65  55.85       Circle
#          1    -368.16 -125.49   922.36  -6.01  -8.75  57.99       Circle
#          2    -470.21   88.87   870.61   3.14  -3.45  58.84       Circle
#          3    -543.46  161.13   878.91  -0.21   2.01  60.46       Circle
#          4    -534.67  185.55   886.72  -7.87 -14.18  59.66       Circle
# ...               ...     ...      ...    ...    ...    ...          ...
# 49       95    -54.69  158.69   234.86  52.90 -22.38  23.90  Up and down
#          96    -14.16  201.17   340.33  77.96 -39.24   0.58  Up and down
#          97     58.59   85.94   464.36  87.04 -32.96  -4.97  Up and down
#          98      1.46   34.67   846.68  90.06 -26.92 -22.65  Up and down
#          99    -84.47   60.06  1194.34  86.07 -47.13 -32.44  Up and down
#
# [6600 rows x 7 columns]

# %%
# Now separate features (X) and labels (y).
# Each instance's label is constant across time steps,
# so we typically grab the first label for each instance.
y = totalDataFrame_shuffled.groupby('instance')['label'].first()

X = totalDataFrame_shuffled.drop(columns=['label'])
X = X.astype(float)

rocket = RocketClassifier()

# %%
print(len(X), len(y))
# Out:
# 6600 66

# %%
# Fit RocketClassifier
rocket.fit(X, y)

print("Fit successful!")
# Out:
# Fit successful!

# %%
X_test_single = X.loc[[49]]

# %%
X_test_single
# Out:
#                 acc_x   acc_y    acc_z  gyr_x  gyr_y  gyr_z
# instance time
# 49       0    -160.64   86.43   432.13 -77.16  16.25   1.52
#          1    -143.07  156.74   340.82 -61.34  25.09  10.03
#          2     -54.20  157.23   220.21 -32.99  23.48  27.23
#          3     -37.11  160.16   128.42 -16.68  29.91  32.87
#          4     -17.58   93.26   117.19   3.17  32.16  31.68
# ...               ...     ...      ...    ...    ...    ...
#          95    -54.69  158.69   234.86  52.90 -22.38  23.90
#          96    -14.16  201.17   340.33  77.96 -39.24   0.58
#          97     58.59   85.94   464.36  87.04 -32.96  -4.97
#          98      1.46   34.67   846.68  90.06 -26.92 -22.65
#          99    -84.47   60.06  1194.34  86.07 -47.13 -32.44
#
# [100 rows x 6 columns]

# %%
y_pred_single = rocket.predict(X_test_single)

# %%
y_pred_single
# Out:
# array(['Up and down'], dtype='<U11')

# %%
####################################

# %%
totalDataFrame_shuffled.loc[39]

# %%
y_data = totalDataFrame_shuffled['label']

# %%
X_data = totalDataFrame_shuffled.drop('label', axis=1)

# %%
y_data

# %%
X_data

# %%
# ---------------------------------

# %%
X_data_train, X_data_test, y_data_train, y_data_test = train_test_split(
    X_data, y_data, test_size=0.2, random_state=42, shuffle=False
)

# %%
X_data_train

# %%
y_data_train

# %%
X_data_train.info()

# %%
check_is_mtype(X_data_train, "nested_univ")

# %%
y_data_train.info()

# %%
print(len(X_data_train), len(y_data_train))

# %%
rocket = RocketClassifier(n_features_per_kernel=6, n_jobs=-1, random_state=42)

# %%
y = df.groupby('instance')['label'].first()
X = df.drop(columns=['label'])

# %%
rocket.fit(X_data_train, y_data_train)
