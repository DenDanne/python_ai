# %%
# !pip install sktime
# Out:
# Requirement already satisfied: sktime in c:\users\danne\anaconda3\lib\site-packages (0.36.0)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.4.2)
# Requirement already satisfied: numpy<2.3,>=1.21 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.26.4)
# Requirement already satisfied: packaging in c:\users\danne\anaconda3\lib\site-packages (from sktime) (24.1)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (2.2.2)
# Requirement already satisfied: scikit-base<0.13.0,>=0.6.1 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (0.12.0)
# Requirement already satisfied: scikit-learn<1.7.0,>=0.24 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.5.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in c:\users\danne\anaconda3\lib\site-packages (from sktime) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danne\anaconda3\lib\site-packages (from pandas<2.3.0,>=1.1->sktime) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danne\anaconda3\lib\site-packages (from pandas<2.3.0,>=1.1->sktime) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danne\anaconda3\lib\site-packages (from pandas<2.3.0,>=1.1->sktime) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\danne\anaconda3\lib\site-packages (from scikit-learn<1.7.0,>=0.24->sktime) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\danne\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.1->sktime) (1.16.0)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from time import sleep
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sktime.classification.kernel_based import RocketClassifier
from sktime.datatypes import convert_to
from sktime.datatypes._panel._convert import from_nested_to_3d_numpy
from sktime.datatypes import check_is_mtype

# %%
nr_of_samples_in_one_batch = 100

# %%
def convert(df, list_cols=None, label_col='label'):
    if list_cols is None:
        list_cols = ['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z']

    # 1. Reset index so we have a 'instance' column
    df = df.reset_index(drop=True).rename_axis('instance').reset_index()

    # 2. Explode list columns
    df = df.explode(list_cols, ignore_index=True)

    # 3. Create a 'time' column for each exploded element
    df['time'] = df.groupby('instance').cumcount()

    # 4. Set a MultiIndex of (instance, time)
    df = df.set_index(['instance', 'time'])

    # 5. Convert all non-label columns to float
    numeric_cols = [col for col in df.columns if col != label_col]
    df[numeric_cols] = df[numeric_cols].astype(float)

    return df

# %%
def read_X_samples(X, nr, samples):
    return samples.iloc[(nr*X):(nr*X+X), :]

# %%
def addEntryToDataFrame(df, data, label):
    new_entry = {f"feature_{i}": [np.array(data.iloc[:, i].values, dtype=np.float64)]  # Wrap in list
                 for i in range(data.shape[1])}
    new_entry["label"] = [label]  # Wrap label in list
    
    # Convert to DataFrame
    df_entry = pd.DataFrame(new_entry)

    # Concatenate
    df = pd.concat([df, df_entry], ignore_index=True)
    return df

# %%
def concatenate_dataFrames(dF1, dF2):
    frame = [dF1, dF2]
    return pd.concat(frame, ignore_index=True)

# %%
def renameFeatures(dF):
    preferred_names = ["acc_x", "acc_y", "acc_z", "gyr_x", "gyr_y", "gyr_z", "label"]
    dF.columns = preferred_names[:len(preferred_names)]
    return dF

# %%
def addWholeDatasetToDataFrame(dF, data, label):
    nr_of_batches = round(data.dropna(how='all').shape[0] / nr_of_samples_in_one_batch)
    
    for i in range(nr_of_batches):
        batch = read_X_samples(nr_of_samples_in_one_batch, i, data)
        dF = addEntryToDataFrame(dF, batch, label)
    dF = renameFeatures(dF)
    return dF

# %%
def readFile_addToDataFrame(filename, dF, label_name):
    motion = pd.read_csv(filename, na_filter=False, sep=r"\s+", header=None, dtype=np.float64)
    dF = addWholeDatasetToDataFrame(dF, motion, label_name)
    dF["label"] = dF["label"].astype("category")
    return dF

# %%
def shuffle_instances(df):
    # Get unique instance values and shuffle them
    shuffled_instances = shuffle(df.index.levels[0])  # Shuffle the instances
    
    # Reorder the DataFrame based on shuffled instances while keeping time order intact
    df_shuffled = pd.concat([df.loc[i] for i in shuffled_instances], keys=shuffled_instances)

    return df_shuffled

# %%
dF_updown = pd.DataFrame()
dF_circles = pd.DataFrame()

# %%
dF_updown = readFile_addToDataFrame('up_down3.txt', dF_updown, 'Up and down')
dF_circles = readFile_addToDataFrame('circles3.txt', dF_circles, 'Circle')

# %%
dF_updown['acc_x'].dtype, dF_updown['acc_x'][0].dtype, dF_updown['label'].dtype
# Out:
# (dtype('O'),
#  dtype('float64'),
#  CategoricalDtype(categories=['Up and down'], ordered=False, categories_dtype=object))

# %%
print(check_is_mtype(dF_updown, "nested_univ")) # Check if type is correct for sktime
# Out:
# False

# %%
print(type(dF_updown.iloc[0, 0]))
# Out:
# <class 'numpy.ndarray'>

# %%
dF_updown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   50 non-null     object
#  1   acc_y   50 non-null     object
#  2   acc_z   50 non-null     object
#  3   gyr_x   50 non-null     object
#  4   gyr_y   50 non-null     object
#  5   gyr_z   50 non-null     object
#  6   label   50 non-null     category
# dtypes: category(1), object(6)
# memory usage: 2.6+ KB

# %%
dF_circles
# Out:
#                                                 acc_x  \
# 0   [-10.74, -23.93, -10.25, -13.67, -12.21, -27.8...
# 1   [-31.25, -12.7, -11.23, -9.28, -14.65, -14.65,...
# 2   [-23.44, -23.44, -17.09, 4.39, -17.58, -26.86,...
# 3   [-22.95, -20.51, -16.6, -22.46, 5.37, -14.16, ...
# 4   [-25.88, -21.0, -18.55, -19.04, -2.44, -9.77, ...
# 5   [-11.72, -19.04, -18.55, -14.65, -18.07, -18.0...
# 6   [-134.28, -47.36, 18.07, -64.94, -104.0, -161....
# 7   [-10.25, -12.7, -18.55, -24.9, -31.25, -16.11,...
# 8   [-270.02, -398.44, -330.57, -349.12, -327.15, ...
# 9   [-237.3, -331.54, 125.0, -130.37, 168.95, 250....
# 10  [-55.66, -88.87, -81.54, 250.98, 90.82, 447.75...
# 11  [24.9, 78.61, 75.2, 62.01, 141.11, 233.4, 39.5...
# 12  [127.44, 129.39, 113.28, 287.11, -62.5, -91.8,...
# 13  [440.43, 472.17, 27.83, 245.12, 80.57, 135.74,...
# 14  [183.59, 310.55, 300.78, 284.18, 381.35, 382.3...
# 15  [165.53, 42.48, 27.34, 104.98, 312.01, 277.34,...
# 16  [65.92, -146.97, 344.24, 263.18, 597.17, 211.4...
# 17  [-197.75, -149.9, -436.52, -373.05, -367.19, -...
# 18  [-64.94, -49.32, 40.53, -103.52, -246.09, -153...
# 19  [83.01, -242.19, -272.46, -353.52, -265.14, -4...
# 20  [-161.13, -63.48, -328.61, -228.52, -268.55, -...
# 21  [125.49, -49.8, -38.09, -181.15, 43.95, -219.2...
# 22  [383.3, 284.67, 475.59, 511.72, 397.46, 183.11...
# 23  [215.82, 409.67, 278.32, 208.01, 456.05, 402.8...
# 24  [130.86, 125.0, 297.36, 350.59, 169.92, 279.79...
# 25  [-63.48, -173.83, -22.95, 24.41, 69.82, 109.37...
# 26  [-156.74, -271.0, -245.12, -118.65, -293.46, -...
# 27  [-467.77, -361.33, -458.01, -352.54, -276.37, ...
# 28  [-575.2, -436.52, -360.84, -307.62, -459.47, -...
# 29  [-370.61, -368.16, -283.2, -714.36, -415.53, -...
# 27  [-12.41, -0.12, -0.61, -13.29, -4.09, -4.94, -...
# 28  [0.95, -0.55, -3.6, -0.03, 0.06, -3.54, 1.89, ...
# 29  [-1.1, 16.95, 2.26, -15.06, -15.12, -14.97, 0....
# 30  [-8.05, -9.54, 2.13, 8.05, -0.79, -3.32, -1.07...
# 31  [-1.71, -9.12, -3.72, -4.79, -19.24, -14.54, 5...
# 32  [7.93, 0.34, 7.5, 8.14, -16.16, 6.62, 1.19, -6...
# 33  [-5.03, 0.03, -18.02, 2.13, 1.1, -9.39, -14.57...
# 34  [-9.6, 2.04, -0.95, 1.4, -13.51, 2.96, -7.71, ...
# 35  [0.58, -4.3, -10.64, -1.13, -15.18, -12.99, -5...
# 36  [-3.02, 4.45, 1.49, 3.48, -1.68, 3.66, 3.14, -...
# 37  [-10.21, 0.85, 4.73, -5.76, 2.26, -1.13, 5.0, ...
# 38  [-2.65, 0.95, -0.85, -7.01, 3.69, 1.46, -12.62...
# 39  [-8.05, 0.88, 4.88, -7.5, -2.26, 6.95, -6.65, ...
# 40  [-8.51, 8.48, -7.53, -2.04, 2.29, -6.65, 3.69,...
# 41  [-5.61, -14.6, -14.09, -13.23, 14.33, 5.27, -1...
# 42  [-14.79, 8.35, 5.52, 5.06, 19.33, -12.87, 5.61...
# 43  [1.92, -5.03, 2.68, 8.48, -8.75, -4.05, -11.43...
# 44  [8.81, -17.01, -5.64, -8.08, 2.01, 1.13, 0.76,...
# 45  [-8.48, 7.41, 1.37, -10.21, -1.52, 4.21, 10.3,...
# 46  [-3.63, 7.32, 1.83, 7.35, -3.81, 10.09, 0.24, ...
# 47  [0.82, 2.93, 0.73, 6.92, -0.09, -5.21, -11.65,...
# 48  [-0.73, -0.64, 6.65, 2.8, -6.25, -11.07, -14.6...
# 49  [-8.6, 3.51, -6.71, -4.05, 4.7, 3.05, -9.7, 9....
# 50  [-8.38, -6.86, -7.8, -9.54, -2.07, 3.54, -6.46...
#
#                                                 gyr_z   label
# 0   [-1.13, 1.8, 0.03, -1.89, 0.24, -0.55, 1.34, 0...  Circle
# 1   [-1.04, -0.49, -0.43, -1.4, 1.13, 0.03, -1.01,...  Circle
# 2   [-1.98, -0.7, -0.09, -0.09, -1.46, 0.34, -1.16...  Circle
# 3   [0.15, 0.37, 0.15, 2.1, 2.5, -0.46, -1.55, -1....  Circle
# 4   [-0.43, -0.06, -2.04, -1.68, -1.13, 1.71, 1.31...  Circle
# 5   [0.34, -0.15, -0.58, -2.2, 0.34, -0.18, -2.53,...  Circle
# 6   [16.98, 17.68, 41.8, 4.63, -3.14, -22.71, -25....  Circle
# 7   [-0.06, 1.13, -0.61, -0.46, -3.2, -0.21, 1.52,...  Circle
# 8   [58.38, 55.34, 36.19, 42.99, 39.36, 26.62, -1....  Circle
# 9   [-10.61, -10.55, -85.37, -85.88, -80.7, -75.12...  Circle
# 10  [-73.38, -73.23, -51.01, -38.32, -24.39, 0.73,...  Circle
# 11  [-48.69, -29.42, -35.46, -38.02, -8.2, -24.18,...  Circle
# 12  [21.49, 9.05, 5.37, 11.04, 18.54, 19.42, 48.69...  Circle
# 13  [14.66, 19.76, 30.98, 31.37, 4.21, 32.16, 68.8...  Circle
# 14  [-32.35, -15.58, 6.07, 5.18, 5.0, -4.76, -0.18...  Circle
# 15  [-40.43, -43.29, -39.27, -19.05, -25.09, -29.4...  Circle
# 16  [-56.8, -11.92, -62.68, -37.07, -38.63, -38.32...  Circle
# 17  [16.37, 17.93, 0.61, -30.49, -20.46, -40.79, -...  Circle
# 18  [33.02, 25.21, 44.42, 49.05, 29.54, 12.68, 23....  Circle
# 19  [65.55, 48.99, 55.15, 46.89, 27.53, 39.63, 41....  Circle
# 20  [28.32, 46.46, 41.19, 48.57, 23.84, 25.67, 49....  Circle
# 21  [11.04, -20.7, 1.16, -11.16, 20.06, 11.52, 22....  Circle
# 22  [-24.97, -4.21, -17.04, 6.19, 33.57, 24.63, 43...  Circle
# 23  [-33.9, -16.46, -3.45, -14.88, -14.51, 13.45, ...  Circle
# 24  [-55.3, -23.26, -5.79, -11.4, -23.87, -14.3, -...  Circle
# 25  [-35.3, -31.22, -45.09, -29.66, -86.55, -76.1,...  Circle
# 26  [1.49, -21.52, -3.87, -14.3, -8.9, -15.15, -4....  Circle
# 27  [-32.32, -54.39, -41.59, -40.76, -56.59, -67.9...  Circle
# 28  [-48.45, -33.63, -46.49, -40.27, -53.35, -71.8...  Circle
# 29  [10.95, -12.96, -61.92, -101.01, -100.64, -55....  Circle
# 30  [45.95, 42.41, 16.13, 15.79, -13.38, -37.65, -...  Circle
# 31  [50.88, 50.64, 24.76, 28.2, 7.26, -15.4, -40.6...  Circle
# 32  [62.2, 95.49, 84.7, 84.76, 98.14, 76.86, 61.89...  Circle
# 33  [61.65, 76.28, 93.32, 125.64, 113.23, 102.71, ...  Circle
# 34  [16.74, 36.22, 47.04, 86.55, 89.21, 81.62, 80....  Circle
# 35  [-6.19, -16.98, 4.66, 28.23, 44.18, 50.67, 78....  Circle
# 36  [-43.29, -26.13, -35.98, -2.44, 25.52, 69.36, ...  Circle
# 37  [-74.76, -85.21, -73.08, -55.64, -55.73, -41.9...  Circle
# 38  [-84.15, -76.68, -39.36, -51.71, -73.48, -77.7...  Circle
# 39  [-135.06, -80.95, -101.98, -72.41, -84.36, -82...  Circle
# 40  [-108.2, -73.54, -72.99, -59.51, -54.21, -38.4...  Circle
# 41  [-21.86, -69.82, -57.41, -57.29, -65.09, -44.9...  Circle
# 42  [72.13, 76.31, 59.76, 65.73, 65.73, 28.51, 54....  Circle
# 43  [-62.9, 7.26, 66.28, 115.15, 134.3, 141.95, 13...  Circle
# 44  [2.41, 4.18, 26.83, 20.58, 37.53, 43.08, 48.41...  Circle
# 45  [17.23, 8.48, 16.92, 47.93, 36.28, 46.04, 34.1...  Circle
# 46  [-30.24, -26.71, -10.61, 11.98, -2.35, 13.51, ...  Circle
# 47  [-10.55, -0.43, -24.94, 20.79, 30.64, 33.66, 5...  Circle
# 48  [21.83, 40.43, 20.64, 56.71, 53.35, 42.32, 66....  Circle
# 49  [2.53, 13.63, 31.55, 41.89, 57.68, 74.09, 39.2...  Circle
# 50  [-19.24, 5.95, 17.84, 16.95, 48.14, 20.46, 14....  Circle

# %%
print(len(dF_circles.loc[0, 'acc_x']))

for i in range(33):
    print(len(dF_circles.loc[i, 'acc_x']))

print(dF_circles.loc[10, 'acc_x'])
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# [ -55.66  -88.87  -81.54  250.98   90.82  447.75  230.96  406.25  387.21
#   169.92  112.79  -71.29  248.05  229.98   60.55   35.16   30.76 -129.39
#  -144.53 -171.87 -238.77 -166.02 -154.3  -214.84 -235.84 -324.22  -37.6
#  -179.2  -242.68 -468.26 -208.98 -289.06 -278.81 -227.05   19.53   -4.39
#  -152.83  173.83  114.26  457.52  686.04  246.58  267.09  229.49  251.46
#   553.71  201.66  161.13  120.12   49.8   -10.25  -30.27 -157.71 -133.79
#  -160.16 -205.57 -247.07 -332.03 -284.18 -475.1  -219.24 -138.67 -155.27
#    39.06   88.38  -57.62    1.46  -90.82  100.59 -175.78  265.62  129.39
#   117.19  225.1   393.55  422.36  233.89  203.61  322.27  475.1    54.69
#     9.28  139.16   13.18  -71.29 -305.18 -275.39 -363.77 -404.3  -371.09
#  -383.3  -331.54 -420.41 -363.77 -326.17 -214.84  102.54  116.21  -33.69
#   167.48]

# %%
totalDataFrame = concatenate_dataFrames(dF_circles, dF_updown)

# %%
dF_circles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   51 non-null     object
#  1   acc_y   51 non-null     object
#  2   acc_z   51 non-null     object
#  3   gyr_x   51 non-null     object
#  4   gyr_y   51 non-null     object
#  5   gyr_z   51 non-null     object
#  6   label   51 non-null     category
# dtypes: category(1), object(6)
# memory usage: 2.7+ KB

# %%
dF_updown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   50 non-null     object
#  1   acc_y   50 non-null     object
#  2   acc_z   50 non-null     object
#  3   gyr_x   50 non-null     object
#  4   gyr_y   50 non-null     object
#  5   gyr_z   50 non-null     object
#  6   label   50 non-null     category
# dtypes: category(1), object(6)
# memory usage: 2.6+ KB

# %%
totalDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   101 non-null    object
#  1   acc_y   101 non-null    object
#  2   acc_z   101 non-null    object
#  3   gyr_x   101 non-null    object
#  4   gyr_y   101 non-null    object
#  5   gyr_z   101 non-null    object
#  6   label   101 non-null    object
# dtypes: object(7)
# memory usage: 5.7+ KB

# %%
#for row in range(len(totalDataFrame)):
 #   print(totalDataFrame.iloc[row])

# %%
totalDataFrame
# Out:
#                                                  acc_x  \
# 0    [-10.74, -23.93, -10.25, -13.67, -12.21, -27.8...
# 1    [-31.25, -12.7, -11.23, -9.28, -14.65, -14.65,...
# 2    [-23.44, -23.44, -17.09, 4.39, -17.58, -26.86,...
# 3    [-22.95, -20.51, -16.6, -22.46, 5.37, -14.16, ...
# 4    [-25.88, -21.0, -18.55, -19.04, -2.44, -9.77, ...
# ..                                                 ...
# 96   [-38.09, -32.23, -45.9, -85.94, -72.27, -62.99...
# 97   [59.57, 64.45, 15.14, 9.77, 66.41, 78.12, 81.5...
# 98   [-80.57, -89.84, -91.31, -125.49, -115.23, -10...
# 99   [-38.57, 16.11, -22.95, -56.64, -67.87, -28.81...
# 100  [49.32, 32.23, 101.07, 104.0, 55.18, -28.32, -...
#
#                                                  acc_y  \
# 0    [-6.84, 4.39, 5.86, -3.91, -4.39, -5.86, -3.42...
# 1    [-0.49, 13.18, 2.93, -4.39, 1.95, 0.49, 5.37, ...
# 2    [-2.44, 4.88, 4.88, 2.93, 0.0, 9.77, 0.98, -1....
# 3    [8.79, 0.0, 5.37, -3.42, -3.42, -13.18, -5.37,...
# 4    [-1.95, -0.49, -6.35, 4.88, 2.93, 1.46, 7.32, ...
# ..                                                 ...
# 96   [47.36, 38.57, 63.96, 79.1, 93.75, 64.94, 50.2...
# 97   [-326.17, -416.5, -371.58, -437.99, -453.61, -...
# 98   [18.07, 80.08, 60.06, 57.13, 58.59, 69.82, 85....
# 99   [-39.06, -76.66, -103.52, -203.12, -209.47, -2...
# 100  [114.75, 117.68, 97.17, 128.91, 150.88, 111.82...
#
#                                                  acc_z  \
# 0    [1033.2, 1035.64, 1040.53, 1021.48, 1044.92, 1...
# 1    [1034.18, 1036.62, 1034.67, 1033.2, 1042.48, 1...
# 2    [1031.74, 1047.36, 1036.13, 1029.79, 1043.95, ...
# 3    [1047.36, 1042.48, 1041.02, 1045.9, 1022.95, 1...
# 4    [1041.99, 1042.97, 1042.97, 1044.92, 1048.34, ...
# ..                                                 ...
# 96   [41.02, 26.86, -40.53, 27.83, 111.33, 312.01, ...
# 97   [2240.23, 2333.98, 2222.17, 2174.32, 2114.75, ...
# 98   [378.91, 230.96, 104.0, 48.83, -34.67, -85.94,...
# 99   [1783.69, 1958.01, 2212.89, 2287.6, 2137.7, 20...
# 100  [182.62, 107.42, -12.7, -123.05, -167.97, -157...
#
#                                                  gyr_x  \
# 0    [-1.49, -2.07, -0.27, -1.49, -0.55, -0.85, 0.9...
# 1    [-3.57, -1.22, 0.09, -2.5, -3.6, -0.76, -1.25,...
# 2    [0.27, 0.49, 1.31, -1.22, -0.52, -0.73, -1.16,...
# 3    [-2.44, -0.34, -0.98, -0.12, 0.7, -0.27, -0.03...
# 4    [-2.35, -1.83, 0.09, -1.37, -0.34, -0.3, 0.3, ...
# ..                                                 ...
# 96   [-22.74, -4.05, 19.21, 45.03, 72.04, 92.32, 96...
# 97   [80.91, 47.87, 26.92, 8.66, -21.49, -52.35, -7...
# 98   [-109.36, -88.17, -60.12, -33.78, -7.65, 17.99...
# 99   [102.47, 71.83, 42.26, 26.95, 18.78, 2.38, -21...
# 100  [-94.21, -58.87, -19.76, 5.24, 31.95, 54.05, 6...
#
#                                                  gyr_y  \
# 0    [-2.68, -1.19, -1.55, -0.61, -2.07, -3.41, -1....
# 1    [-1.86, -3.29, -0.3, 0.73, -1.89, -0.88, -0.88...
# 2    [-3.05, -3.35, -1.68, -1.31, -0.15, -2.9, -0.9...
# 3    [-2.01, -0.43, -2.65, -2.8, -2.62, -1.95, -0.9...
# 4    [-0.82, -0.4, 0.24, -1.65, 1.19, -1.8, -1.52, ...
# ..                                                 ...
# 96   [-6.22, -11.77, -23.87, -25.82, -17.01, -9.7, ...
# 97   [0.55, -24.7, -16.01, 17.2, 28.87, 27.53, 17.5...
# 98   [6.1, 5.34, 4.48, 5.37, -1.22, -6.07, -6.62, -...
# 99   [-47.1, -61.98, -51.1, -39.91, -7.53, 25.49, 3...
# 100  [8.29, 23.75, 29.18, 10.67, -14.27, -26.37, -2...
#
#                                                  gyr_z        label
# 0    [-1.13, 1.8, 0.03, -1.89, 0.24, -0.55, 1.34, 0...       Circle
# 1    [-1.04, -0.49, -0.43, -1.4, 1.13, 0.03, -1.01,...       Circle
# 2    [-1.98, -0.7, -0.09, -0.09, -1.46, 0.34, -1.16...       Circle
# 3    [0.15, 0.37, 0.15, 2.1, 2.5, -0.46, -1.55, -1....       Circle
# 4    [-0.43, -0.06, -2.04, -1.68, -1.13, 1.71, 1.31...       Circle
# ..                                                 ...          ...
# 96   [13.69, 22.26, 24.3, 19.97, 15.21, 16.8, 22.71...  Up and down
# 97   [-22.01, -24.42, -13.9, 2.01, 6.98, 5.67, 5.37...  Up and down
# 98   [6.65, 5.91, 9.33, 10.61, 13.41, 5.34, 2.07, -...  Up and down
# 99   [-13.26, -23.93, -29.88, -27.59, -8.11, 2.62, ...  Up and down
# 100  [4.36, 18.2, 31.95, 31.68, 31.62, 17.04, 4.33,...  Up and down
#
# [101 rows x 7 columns]

# %%
totalDataFrame = convert(totalDataFrame)

# %%
totalDataFrame
# Out:
#                acc_x  acc_y    acc_z   gyr_x  gyr_y  gyr_z        label
# instance time
# 0        0    -10.74  -6.84  1033.20   -1.49  -2.68  -1.13       Circle
#          1    -23.93   4.39  1035.64   -2.07  -1.19   1.80       Circle
#          2    -10.25   5.86  1040.53   -0.27  -1.55   0.03       Circle
#          3    -13.67  -3.91  1021.48   -1.49  -0.61  -1.89       Circle
#          4    -12.21  -4.39  1044.92   -0.55  -2.07   0.24       Circle
# ...              ...    ...      ...     ...    ...    ...          ...
# 100      95   -41.02  25.88   138.18   94.97  -7.41  13.81  Up and down
#          96   -49.80  50.29   308.11  111.16   0.58  17.90  Up and down
#          97   -49.80  18.07   653.32  105.79  -2.93  15.49  Up and down
#          98     3.42  33.20   942.38   95.82 -15.12  22.56  Up and down
#          99   -19.53  45.90  1196.29   99.82 -39.24  18.60  Up and down
#
# [10100 rows x 7 columns]

# %%
totalDataFrame_shuffled = shuffle_instances(totalDataFrame)

# %%
totalDataFrame_shuffled
# Out:
#                 acc_x   acc_y    acc_z  gyr_x  gyr_y  gyr_z   label
# instance time
# 3        0     -22.95    8.79  1047.36  -2.44  -2.01   0.15  Circle
#          1     -20.51    0.00  1042.48  -0.34  -0.43   0.37  Circle
#          2     -16.60    5.37  1041.02  -0.98  -2.65   0.15  Circle
#          3     -22.46   -3.42  1045.90  -0.12  -2.80   2.10  Circle
#          4       5.37   -3.42  1022.95   0.70  -2.62   2.50  Circle
# ...               ...     ...      ...    ...    ...    ...     ...
# 14       95    -21.97  313.96   784.18  -5.06  13.66 -49.18  Circle
#          96      1.46  443.36   990.72 -12.47 -18.54 -40.67  Circle
#          97     64.45  288.09  1194.34   6.34   0.76 -36.62  Circle
#          98    317.38  447.27  1353.52  -1.16   0.98 -28.14  Circle
#          99    213.87  242.19  1116.70  -6.86  13.48 -40.88  Circle
#
# [10100 rows x 7 columns]

# %%
# Get unique instances
unique_instances = totalDataFrame_shuffled.index.get_level_values('instance').unique()

# Compute the number of instances to take
num_instances = int(0.15 * len(unique_instances))

# Select the first 15% of instances
selected_instances = unique_instances[:num_instances]

# Create test dataframe
test_dataframe = totalDataFrame_shuffled.loc[selected_instances]

totalDataFrame_shuffled = totalDataFrame_shuffled.drop(index=selected_instances, level='instance')

# %%
totalDataFrame_shuffled
# Out:
#                 acc_x   acc_y    acc_z  gyr_x  gyr_y  gyr_z   label
# instance time
# 1        0     -31.25   -0.49  1034.18  -3.57  -1.86  -1.04  Circle
#          1     -12.70   13.18  1036.62  -1.22  -3.29  -0.49  Circle
#          2     -11.23    2.93  1034.67   0.09  -0.30  -0.43  Circle
#          3      -9.28   -4.39  1033.20  -2.50   0.73  -1.40  Circle
#          4     -14.65    1.95  1042.48  -3.60  -1.89   1.13  Circle
# ...               ...     ...      ...    ...    ...    ...     ...
# 14       95    -21.97  313.96   784.18  -5.06  13.66 -49.18  Circle
#          96      1.46  443.36   990.72 -12.47 -18.54 -40.67  Circle
#          97     64.45  288.09  1194.34   6.34   0.76 -36.62  Circle
#          98    317.38  447.27  1353.52  -1.16   0.98 -28.14  Circle
#          99    213.87  242.19  1116.70  -6.86  13.48 -40.88  Circle
#
# [8600 rows x 7 columns]

# %%
test_dataframe
# Out:
#                 acc_x  acc_y    acc_z  gyr_x  gyr_y  gyr_z        label
# instance time
# 3        0     -22.95   8.79  1047.36  -2.44  -2.01   0.15       Circle
#          1     -20.51   0.00  1042.48  -0.34  -0.43   0.37       Circle
#          2     -16.60   5.37  1041.02  -0.98  -2.65   0.15       Circle
#          3     -22.46  -3.42  1045.90  -0.12  -2.80   2.10       Circle
#          4       5.37  -3.42  1022.95   0.70  -2.62   2.50       Circle
# ...               ...    ...      ...    ...    ...    ...          ...
# 60       95   -115.23 -72.27   253.42 -23.90 -18.84   0.40  Up and down
#          96   -105.47  41.50   135.25 -11.40 -11.74 -11.10  Up and down
#          97   -125.49  35.64   179.69   5.06   1.16 -13.14  Up and down
#          98    -62.99   9.77   161.13  32.20   3.32   1.86  Up and down
#          99     11.72 -15.63   189.94  48.41   1.68  -2.20  Up and down
#
# [1500 rows x 7 columns]

# %%
# Now separate features (X) and labels (y).
# Each instance's label is constant across time steps,
# so we typically grab the first label for each instance.
y_train = totalDataFrame_shuffled.groupby('instance')['label'].first()
X_train = totalDataFrame_shuffled.drop(columns=['label'])
X_train = X_train.astype(float)

y_test = test_dataframe.groupby('instance')['label'].first()
X_test = test_dataframe.drop(columns=['label'])
X_test = X_test.astype(float)


rocket = RocketClassifier()

# %%
y_train
# Out:
# instance
# 0           Circle
# 1           Circle
# 2           Circle
# 4           Circle
# 5           Circle
#           ...
# 95     Up and down
# 96     Up and down
# 98     Up and down
# 99     Up and down
# 100    Up and down
# Name: label, Length: 86, dtype: object

# %%
X_train
# Out:
#                 acc_x   acc_y    acc_z  gyr_x  gyr_y  gyr_z
# instance time
# 1        0     -31.25   -0.49  1034.18  -3.57  -1.86  -1.04
#          1     -12.70   13.18  1036.62  -1.22  -3.29  -0.49
#          2     -11.23    2.93  1034.67   0.09  -0.30  -0.43
#          3      -9.28   -4.39  1033.20  -2.50   0.73  -1.40
#          4     -14.65    1.95  1042.48  -3.60  -1.89   1.13
# ...               ...     ...      ...    ...    ...    ...
# 14       95    -21.97  313.96   784.18  -5.06  13.66 -49.18
#          96      1.46  443.36   990.72 -12.47 -18.54 -40.67
#          97     64.45  288.09  1194.34   6.34   0.76 -36.62
#          98    317.38  447.27  1353.52  -1.16   0.98 -28.14
#          99    213.87  242.19  1116.70  -6.86  13.48 -40.88
#
# [8600 rows x 6 columns]

# %%
print("Train: ", len(X_train), len(y_train))
print("Test: ", len(X_test), len(y_test))
# Out:
# Train:  8600 86
# Test:  1500 15

# %%
# Fit RocketClassifier
rocket.fit(X_train, y_train)

print("Fit successful!")
# Out:
# Fit successful!

# %%
y_pred = rocket.predict(X_test)

# %%
y_pred
# Out:
# array(['Circle', 'Circle', 'Circle', 'Up and down', 'Up and down',
#        'Circle', 'Up and down', 'Up and down', 'Up and down',
#        'Up and down', 'Circle', 'Circle', 'Circle', 'Circle',
#        'Up and down'], dtype='<U11')

# %%
y_test
# Out:
# instance
# 3          Circle
# 16         Circle
# 20         Circle
# 22         Circle
# 25         Circle
# 41         Circle
# 43         Circle
# 45         Circle
# 57    Up and down
# 58    Up and down
# 60    Up and down
# 67    Up and down
# 70    Up and down
# 74    Up and down
# 97    Up and down
# Name: label, dtype: object

# %%
####################################

# %%
totalDataFrame_shuffled.loc[39]
# Out:
#        acc_x   acc_y    acc_z  gyr_x  gyr_y   gyr_z   label
# time
# 0    -513.67  117.19  1102.05   3.72  -8.05 -135.06  Circle
# 1    -722.17  324.22  1211.91  -0.37   0.88  -80.95  Circle
# 2    -564.94  337.89   993.65  -3.29   4.88 -101.98  Circle
# 3    -465.82  221.19   876.46   4.54  -7.50  -72.41  Circle
# 4    -259.28  460.45  1074.71   8.75  -2.26  -84.36  Circle
# ...      ...     ...      ...    ...    ...     ...     ...
# 95   -358.89 -335.45   996.58   3.41   3.75   28.63  Circle
# 96   -294.92  -74.22  1182.13  -4.15  -7.59   12.77  Circle
# 97   -372.56 -192.87   869.63  -7.68  -1.01    4.05  Circle
# 98   -371.09 -399.41   973.63 -17.26   2.90  -43.23  Circle
# 99   -358.40   35.64  1126.46   9.85  -3.84 -103.02  Circle
#
# [100 rows x 7 columns]

# %%
y_data = totalDataFrame_shuffled['label']

# %%
X_data = totalDataFrame_shuffled.drop('label', axis=1)

# %%
y_data
# Out:
# instance  time
# 1         0       Circle
#           1       Circle
#           2       Circle
#           3       Circle
#           4       Circle
#                    ...
# 14        95      Circle
#           96      Circle
#           97      Circle
#           98      Circle
#           99      Circle
# Name: label, Length: 8600, dtype: object

# %%
X_data
# Out:
#                 acc_x   acc_y    acc_z  gyr_x  gyr_y  gyr_z
# instance time
# 1        0     -31.25   -0.49  1034.18  -3.57  -1.86  -1.04
#          1     -12.70   13.18  1036.62  -1.22  -3.29  -0.49
#          2     -11.23    2.93  1034.67   0.09  -0.30  -0.43
#          3      -9.28   -4.39  1033.20  -2.50   0.73  -1.40
#          4     -14.65    1.95  1042.48  -3.60  -1.89   1.13
# ...               ...     ...      ...    ...    ...    ...
# 14       95    -21.97  313.96   784.18  -5.06  13.66 -49.18
#          96      1.46  443.36   990.72 -12.47 -18.54 -40.67
#          97     64.45  288.09  1194.34   6.34   0.76 -36.62
#          98    317.38  447.27  1353.52  -1.16   0.98 -28.14
#          99    213.87  242.19  1116.70  -6.86  13.48 -40.88
#
# [8600 rows x 6 columns]

# %%
# ---------------------------------

# %%
X_data_train, X_data_test, y_data_train, y_data_test = train_test_split(
    X_data, y_data, test_size=0.2, random_state=42, shuffle=False
)

# %%
X_data_train
# Out:
#                acc_x  acc_y    acc_z   gyr_x  gyr_y  gyr_z
# instance time
# 1        0    -31.25  -0.49  1034.18   -3.57  -1.86  -1.04
#          1    -12.70  13.18  1036.62   -1.22  -3.29  -0.49
#          2    -11.23   2.93  1034.67    0.09  -0.30  -0.43
#          3     -9.28  -4.39  1033.20   -2.50   0.73  -1.40
#          4    -14.65   1.95  1042.48   -3.60  -1.89   1.13
# ...              ...    ...      ...     ...    ...    ...
# 84       75    42.97  11.72   814.45 -105.76 -64.33  -9.85
#          76    -4.39  65.92   550.29  -78.99 -78.81 -10.06
#          77   -21.00  67.87   275.88  -61.34 -70.06  -1.98
#          78   -42.48  23.44   140.62  -41.04 -58.17   0.67
#          79   -43.95  28.81   -15.63  -26.04 -40.43   7.29
#
# [6880 rows x 6 columns]

# %%
y_data_train
# Out:
# instance  time
# 1         0            Circle
#           1            Circle
#           2            Circle
#           3            Circle
#           4            Circle
#                      ...
# 84        75      Up and down
#           76      Up and down
#           77      Up and down
#           78      Up and down
#           79      Up and down
# Name: label, Length: 6880, dtype: object

# %%
X_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6880 entries, (1, 0) to (84, 79)
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acc_x   6880 non-null   float64
#  1   acc_y   6880 non-null   float64
#  2   acc_z   6880 non-null   float64
#  3   gyr_x   6880 non-null   float64
#  4   gyr_y   6880 non-null   float64
#  5   gyr_z   6880 non-null   float64
# dtypes: float64(6)
# memory usage: 345.7 KB

# %%
check_is_mtype(X_data_train, "nested_univ")
# Out:
# False

# %%
y_data_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 6880 entries, (1, 0) to (84, 79)
# Series name: label
# Non-Null Count  Dtype
# --------------  -----
# 6880 non-null   object
# dtypes: object(1)
# memory usage: 77.0+ KB

# %%
print(len(X_data_train), len(y_data_train))
# Out:
# 6880 6880

# %%
rocket = RocketClassifier(n_features_per_kernel=6, n_jobs=-1, random_state=42)

# %%
y = df.groupby('instance')['label'].first()
X = df.drop(columns=['label'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[363], line 1
# ----> 1 y = df.groupby('instance')['label'].first()
#       2 X = df.drop(columns=['label'])
#
# NameError: name 'df' is not defined

# %%
rocket.fit(X_data_train, y_data_train)
